# %%
import matplotlib.pyplot as plt
import numpy as np
import pdb
import pandas as pd

# %%
#question 1
df=pd.read_csv('fdata.csv')
df
df.plot()
plt.show()

# %%
#question 2
data=[  (3-10-16, 772.559998),
        (4-10-16, 776.429993),
        (5-10-16, 776.469971),
        (6-10-16, 776.859985),
        (7-10-16, 775.080017),
     ]
plt.grid(b=True,color='red')
plt.title("closing stock value of Alphabet inc.")
plt.xlabel("Data")
plt.ylabel("closing value")
arr=np.array(data)
date=arr.T[0].tolist()
close=arr.T[1]
plt.minorticks_on()
plt.plot(date,close,color='red',marker='o',linestyle='solid')
plt.show()

# %%
#question 3
popularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
language=['java','python','php','javascript','c#','c++']
plt.bar(language,popularity)
plt.title('popularity of programming language \n worldwide, oct 2017 compared to a year ago')
plt.xlabel("Language")
plt.ylabel("popularity")
plt.grid()
plt.show()

# %%
#question 4
popularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
language=['java','python','php','javascript','c#','c++']
plt.grid()
plt.barh(language,popularity)
plt.show()

# %%
#question 5
weight1= [67,57.2,59.6,59.64,55.8,61.2,60.45,61,56.23,56]
height1= [101.7,197.6,98.3,125.1,113.7,157.7,136,148.9,125.3,114.9]
weight2= [61.9,64,62.1,64.2,62.3,65.4,62.4,61.4,62.5,63.6]
height2= [152.8,155.3,135.1,125.2,151.3,135,182.2,195.9,165.1,125.1]
weight3= [68.2,67.2,68.4,68.7,71,71.3,70.8,70,71.1,71.7]
height3= [165.8,170.9,192.8,135.4,161.4,136.1,167.1,235.1,181.1,177.3]
   
plt.scatter(weight1,height1,c='red',marker=(5,1))
plt.scatter(weight2,height2,c="green",marker=(5,1))
plt.scatter(weight3,height3,c='blue',marker=(5,1))

plt.xlabel('Weight')
plt.ylabel('Height')
plt.title('Group Wise Weight vs Height')
plt.show()
